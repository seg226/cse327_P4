# %% [markdown]
# The block below imports a necessary module and checks if you are in the right directory. If you do not see a list of python files when you run the block, please make sure you have uploaded the zip file and unzipped it.

# %%
import matplotlib.pyplot as plt

# %pwd
# %ls
# Out:
#  atomgenerator.py    custom_lotr_kb.txt   kbencoder.py          reasoner.py
#  autoencoder.py      embedmodel.py        kbparser.py           size200/
#  basictypes.py       evaluate.py          knowledgebase.py      size300/
#  chainbased.py       gameofthrones.txt    mr_back_reasoner.py   termwalk.py
# 'CSE 327 P4.ipynb'   gen_queries.py       nnreasoner.py         vocab.py
#  custom_LOTR_kb/     helpers/             nnunifier.py

# %% [markdown]
# If you want to create a random knowledge base, run the following code.
#
# Creates the files:
#
# * randomKB.txt - A random KB generated using 10 predicates and 100 constants.
# * vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --generate_kb --new_vocab --save_vocab
# !head randomKB.txt
# Out:
# Classes: 100000000000.0
# Max arity: 5
# KB generated (150)
# p1(a23, a62).
# p4(a28, a10, a59, a15, a0).
# p2(a14, a7).
# p3(a0).
# p6(a59, a56).
# p4(a13, a80, a22, a76, a2).
# p6(a4, a73).
# p1(a46, a93).
# p0(a10, a89).
# p9(a84, a0).

# %% [markdown]
# The following code prepares an existing knowledge base (KB) for use. To use a KB of your choosing, replace gameofthrones.txt with the file name of any KB you want to use.
#
# Creates the file:
#
# *   vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt --vocab_from_kb --save_vocab
# Out:
# Creating vocabulary from last gameofthrones.txt knowledge base

# %% [markdown]
# Train a neural net to convert first-order logic atoms into meaningful numeric vectors. We call these vectors "embeddings," and the learned model the embedding model. The code creates random atoms and then uses a mechanism known as triplet loss to place unifying atoms closer together.
#
# Creates the files:
#
# *   rKB_model.pth - Saves the learned weights for the embedding model
# *   training_loss-45-106-2-50.png - A plot of the training loss after each epoch. This file's name depends on the vocabulary of your KB: the four numbers are number of predicates, number of constants, max arity of the predicates, and the embedding size used. If you changed the KB, you'll need to look up the name in your drive and update the code block that displays this file.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [█████---------------] 18245/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [█████████████-------] 48975/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [████████████████████] 70000/70000 Triplet encodings
# Early stopping triggered-------------] 32.3% Epoch | [Epoch 162/500, Training Loss: 0.0694, Validation Loss: 0.2986]
# Saved model.
# Saved plot.
# unification model generated

# %%
img = plt.imread('training_loss-45-106-2-50.png')
plt. imshow(img)

# %% [markdown]
# Generate a set of train and test queries from your knowledge base. This will also generate the deductive closure (all facts that can be inferred) of your KB using forward-chaining.
#
# Produces the files:
#
# *  all_facts.txt - A list of all facts that can be inferred from the KB. This is used to generate queries that are guaranteed to have an answer.
# *  train_queries.txt - A set of training queries where each will have at least one answer.
# *  test_queries.txt - A set of test queries where each will have at least one answer.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 442
# Forward chaining depth: 2
# New facts: 175
# Forward chaining depth: 3
# New facts: 82
# Forward chaining depth: 4
# New facts: 12
# Forward chaining depth: 5
# New facts: 1
# Forward chaining depth: 6
# New facts: 2
# Forward chaining depth: 7
#
# Facts list generated
# 714 total facts. Max depth = 6
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %% [markdown]
# Create a training set for the scoring model. The examples will consist of goal, rule, score pairs, where a score of 1 means the rule can solve the goal, and 0 means it cannot. It runs the full set of training queries with a randomized backward-chaining process. This step can sometimes take a long time and is not able to take advantage of a GPU (with the gameofthrones KB it took ~45 minutes).
#
# Creates a file:
# *  mr_train_examples.csv - Contains a line for each goal/rule/score example.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [descendant(_EX4, _EX6)]
# min depth: 5
# Nodes: 21287
# Answers: 190
#
# 2: [son(Z, X)]
# min depth: 3
# Nodes: 121
# Answers: 72
#
# 3: [who_brought_the_winter(X), who_killed_dragons(X)]
# min depth: 3
# Nodes: 4
# Answers: 1
#
# 4: [ancestor(_EX0, _EX3)]
# Restart...
# Restart...
# min depth: 4
# Nodes: 24325
# Answers: 208
#
# 5: [mother_dragons(Y, X), destroy(X, Z), destroy(X, capital), father(aerys_targaryen, Y)]
# min depth: 1
# Nodes: 4
# Answers: 3
#
# 6: [ancestor(catelyn_stark, X), mother(catelyn_stark, X)]
# min depth: 2
# Nodes: 9301
# Answers: 5
#
# 7: [ancestor(aerys_targaryen, _EX2)]
# Restart...
# min depth: 4
# Nodes: 23841
# Answers: 6
#
# 8: [child(_EX0, unknown_father_greyjoy)]
# min depth: 2
# Nodes: 5
# Answers: 3
#
# 9: [ancestor(tytos_lannister, Z)]
# min depth: 2
# Nodes: 46023
# Answers: 20
#
# 10: [child(arya_stark, _EX5)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 11: [descendant(four_unknown_martells, _EX1)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 26049
# Answers: 4
#
# 12: [mother(X, Y), female(X), descendant(Y, Z), son(daeron_targaryen, Z)]
# min depth: 3
# Nodes: 155
# Answers: 49
#
# 13: [child(Z, _EX1)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 14: [ancestor(cassana_estermont, gendry)]
# Restart...
# Restart...
# Answers: 0
#
# 15: [status(polliver, X), status(rodrick_greyjoy, X)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 16: [father(_EX6, benjen_stark)]
# min depth: 3
# Nodes: 5
# Answers: 1
#
# 17: [descendant(bran_stark, _EX5)]
# Restart...
# min depth: 3
# Nodes: 20690
# Answers: 3
#
# 18: [descendant(sansa_stark, X)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 349
# Answers: 6
#
# 19: [father(_EX2, Y)]
# min depth: 3
# Nodes: 103
# Answers: 54
#
# 20: [child(_EX3, X)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 21: [ancestor(Z, X), ancestor(Y, X), parent(Y, viserys_targaryen), mother(Z, rhaenys_targaryen), ancestor(Z, rhaenys_targaryen)]
# min depth: 2
# Nodes: 100114
# Answers: 132
#
# 22: [descendant(bran_stark, X), parent(X, benjen_stark), ancestor(X, arya_stark)]
# min depth: 3
# Nodes: 28795
# Answers: 2
#
# 23: [descendant(X, unknown_mother_sand_3), female(X), descendant(X, lewyn_martell), parent(oberyn_martell, X)]
# Restart...
# Restart...
# Answers: 0
#
# 24: [ancestor(Z, _EX4)]
# Restart...
# min depth: 2
# Nodes: 29512
# Answers: 186
#
# 25: [son(rodrick_greyjoy, X), son(maron_greyjoy, X)]
# min depth: 3
# Nodes: 6
# Answers: 2
#
# 26: [ancestor(X, rodrick_greyjoy), parent(Y, X), descendant(theon_greyjoy, Y), descendant(rodrick_greyjoy, Y)]
# min depth: 2
# Nodes: 26349
# Answers: 4
#
# 27: [status(the_mountain, X), status(sansa_stark, X)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 28: [ancestor(_EX4, _EX6)]
# min depth: 4
# Nodes: 21257
# Answers: 228
#
# 29: [descendant(_EX1, _EX4)]
# min depth: 7
# min depth: 5
# Nodes: 36427
# Answers: 188
#
# 30: [ancestor(unknown_mother_martell, _EX6)]
# min depth: 4
# Nodes: 49761
# Answers: 11
#
# 31: [ancestor(unknown_father_greyjoy, _EX6)]
# min depth: 2
# Nodes: 865
# Answers: 3
#
# 32: [descendant(_EX0, _EX5)]
# min depth: 3
# Nodes: 46466
# Answers: 189
#
# 33: [betray(Y, X), male(X), ancestor(Z, Y), daughter(Y, Z), parent(X, joffery_lannister)]
# min depth: 1
# Nodes: 8
# Answers: 7
#
# 34: [status(X, Z), ancestor(Y, X), child(X, kevan_lannister), parent(Y, kevan_lannister), status(cassana_estermont, Z)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 35: [child(X, mellario_of_norvos), son(X, doran_martell)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 36: [ancestor(_EX5, Z)]
# min depth: 2
# Nodes: 1534
# Answers: 232
#
# 37: [father(_EX6, balon_greyjoy)]
# min depth: 3
# Nodes: 50
# Answers: 1
#
# 38: [ancestor(unknown_mother_stark, _EX3)]
# min depth: 2
# Nodes: 9784
# Answers: 8
#
# 39: [ancestor(unknown_mother_targaryen, X)]
# min depth: 2
# Nodes: 42613
# Answers: 13
#
# 40: [father(rickard_stark, eddard_stark)]
# min depth: 3
# Nodes: 4
# Answers: 1
#
# 41: [child(balon_greyjoy, unknown_mother_greyjoy)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 42: [ancestor(unknown_mother_martell, _EX5)]
# Restart...
# min depth: 4
# Nodes: 11691
# Answers: 15
#
# 43: [ancestor(_EX6, _EX3)]
# min depth: 2
# Nodes: 100097
# Answers: 140
#
# 44: [child(gendry, _EX2)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 45: [child(Y, _EX0)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 46: [descendant(X, Z), father(X, Y), ancestor(Z, Y), son(X, Z)]
# Restart...
# min depth: 3
# Nodes: 22911
# Answers: 222
#
# 47: [parent(X, tyene_sand), mother(unknown_mother_martell, X)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 48: [who_is_the_mother_of_dragons(Z)]
# min depth: 2
# Nodes: 5
# Answers: 3
#
# 49: [child(_EX4, selyse_baratheon)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 50: [female(X), father(Y, X), father(Y, joffery_lannister)]
# min depth: 1
# Nodes: 33
# Answers: 32
#
# 51: [daughter(Y, X), mother(X, Y), descendant(Y, oberyn_martell), ancestor(X, Y)]
# min depth: 3
# Nodes: 62
# Answers: 28
#
# 52: [who_loved_daenerys(X), love(X, Y), father(aerys_targaryen, Y)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 53: [child(_EX1, _EX2)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 54: [son(Z, rickard_stark)]
# min depth: 3
# Nodes: 52
# Answers: 3
#
# 55: [ancestor(cersei_lannister, _EX0)]
# Restart...
# Restart...
# Answers: 0
#
# 56: [child(theon_greyjoy, _EX2)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 57: [child(margaery_tyrell, _EX3)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 58: [ancestor(_EX0, lyanna_stark)]
# Restart...
#  [-----] 1.3% to max nodes (1543 nps)^C
# Traceback (most recent call last):
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 1043, in <module>
#     prep_examples(args.train_example_path, args.kb_path,
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 306, in prep_examples
#     async_results.append(gen_example_encodings(
#                          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 165, in gen_example_encodings
#     ans_count = backwardchain(KB, path, reasoner.MaxDepth(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 479, in backwardchain
#     for _ in answers:
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 582, in backwardmain
#     for ret_val in backwardmain(KB, new_G, vars, new_leaf, max_depth, examples, examples_list, start_time):
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 582, in backwardmain
#     for ret_val in backwardmain(KB, new_G, vars, new_leaf, max_depth, examples, examples_list, start_time):
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 582, in backwardmain
#     for ret_val in backwardmain(KB, new_G, vars, new_leaf, max_depth, examples, examples_list, start_time):
#   [Previous line repeated 12 more times]
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/kbencoder.py", line 541, in backwardmain
#     rule_1 = copy(rule)
#              ^^^^^^^^^^
#   File "/opt/tljh/user/envs/cse327python311/lib/python3.11/copy.py", line 84, in copy
#     return copier(x)
#            ^^^^^^^^^
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/knowledgebase.py", line 41, in __copy__
#     return Rule(copy(self.head), [copy(x) for x in self.body])
#                 ^^^^^^^^^^^^^^^
#   File "/opt/tljh/user/envs/cse327python311/lib/python3.11/copy.py", line 84, in copy
#     return copier(x)
#            ^^^^^^^^^
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/basictypes.py", line 135, in __copy__
#     [copy(x) for x in self.arguments])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/basictypes.py", line 135, in <listcomp>
#     [copy(x) for x in self.arguments])
#
# KeyboardInterrupt

# %% [markdown]
# Train the scoring model. This step will usually take several minutes, especially if you are not using a GPU (for the gameofthrones KB, it takes about 30 minutes on CPU).
#
# Creates a file:
# * uni_mr_model.pt - Contains the weights for the learned scoring model

# %%
# !python nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 45
# Max arity: 2
# Num constants: 106
# Num variables: 10
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Traceback (most recent call last):
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/nnreasoner.py", line 354, in <module>
#     train_reasoning_model(
#   File "/data/users/jupyter-mis226/cse327_P4/cse327-p4-files/nnreasoner.py", line 127, in train_reasoning_model
#     with open(training_file, mode="r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'mr_train_examples.csv'

# %%
img = plt.imread('guided_loss-unification45-106-2-50.png')
plt. imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 img = plt.imread('guided_loss-unification45-106-2-50.png')
#       2 plt. imshow(img)
#
# File /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/matplotlib/pyplot.py:2615, in imread(fname, format)
#    2611 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2612 def imread(
#    2613         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2614 ) -> np.ndarray:
# -> 2615     return matplotlib.image.imread(fname, format)
#
# File /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/matplotlib/image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
#    1516         "Please open the URL for reading and pass the "
#    1517         "result to Pillow, e.g. with "
#    1518         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1519         )
# -> 1520 with img_open(fname) as image:
#    1521     return (_pil_png_to_float_array(image)
#    1522             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1523             pil_to_array(image))
#
# File /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/PIL/ImageFile.py:135, in ImageFile.__init__(self, fp, filename)
#     131 self.decodermaxblock = MAXBLOCK
#     133 if is_path(fp):
#     134     # filename
# --> 135     self.fp = open(fp, "rb")
#     136     self.filename = os.fspath(fp)
#     137     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'guided_loss-unification45-106-2-50.png'

# %% [markdown]
# Evaluate the scoring model by running evaluate.py. We compare the standard backward-chaining algorithm (-s) with the one that uses our learned scoring model (-u).
#
# The output lists each query, and then provides a line that gives information about query execution. These are: number of nodes explored in the tree, depth of the solution, execution time in seconds, and the speed of exploring the tree (nodes per second).
#
# The names of the files produced depend on the KB used and the options selected. The code below produces the files:
#
# * std-45-106-2-50.csv - A CSV file with query results for the standard backward-chaining algorithm
# * ming-45-106-2-50.csv - A CSV file with query results for the learned reasoner. ming stands for "min scoring goal" and is the default strategy for deciding how to make use of the scores
#
# If you use a different knowledge base, you will likely get different file names that depend on the features of that KB's vocabulary.

# %%
# !python evaluate.py --kb gameofthrones.txt -s
# !python evaluate.py --kb gameofthrones.txt -u

# %% [markdown]
# The results suggest only minor improvements for the gameofthrones KB: on average 3.75 vs. 4.39 node per query when I ran it. You may get different results due to the randomization of training and random selection of test queries. Larger, more complex KBs can see much larger improvements, sometimes an order of magnitude or more.
#
# The code below shows the first 10 lines of each query result file. A given line has:
# * query sequence number
# * configuration name
# * number of nodes explored
# * depth of solution (0 if no solution found)
# * did the system find a solution (true/false)
# * time in seconds
#
# You can import these files into a spreadsheet in order to create plots or summary statistics.

# %%
# !head std-45-106-2-50.csv
# !head ming-45-106-2-50.csv
